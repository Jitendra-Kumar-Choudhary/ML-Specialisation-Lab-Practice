# %% [markdown]
# ## Practice Lab: Linear Regression

# %% [markdown]
# ## 1 - Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *
import copy
import math
# %matplotlib inline

# %%
x_train, y_train = load_data()
